# %% [markdown]
# # Autoloader with upsert
#
# * Execute Auto Loader code to incrementally ingest data from a location in databrics (to stimulate cloudstorage)
# * Describe what happens when a new file arrives in a directory configured for Auto Loader
# * Upsert row when a new file arrives

# %%
dbutils.fs.rm('/mnt/dataset',True)
dbutils.fs.rm('/mnt/reqd',True)
dbutils.fs.rm('/mnt/dbfslandingzone',True)
# Out:
# Out[312]: True

# %% [markdown]
# # Create fixtures

# %%
# %sql
drop table policy
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql

create table policy (
policy string,
name string,
created date,
amount double) USING DELTA
Location '/mnt/dataset';




insert into policy values
('p0001','ram',cast('1908-03-15' AS DATE),232);


insert into policy values
('p0002','ravi',cast('1991-03-15' AS DATE),222.32);


insert into policy values
('p0001','hrithik',cast('1999-03-15' AS DATE),13442);


insert into policy values
('p0004','rajiv',cast('1991-03-15' AS DATE),222.32);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>1</td><td>1</td></tr></tbody></table></div>

# %%
df=spark.sql("select * from policy")
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>policy</th><th>name</th><th>created</th><th>amount</th></tr></thead><tbody><tr><td>p0001</td><td>hrithik</td><td>1999-03-15</td><td>13442.0</td></tr><tr><td>p0004</td><td>rajiv</td><td>1991-03-15</td><td>222.32</td></tr><tr><td>p0002</td><td>ravi</td><td>1991-03-15</td><td>222.32</td></tr><tr><td>p0001</td><td>ram</td><td>1908-03-15</td><td>232.0</td></tr></tbody></table></div>

# %% [markdown]
# ### Helper function to create json files from delta table
# * Create json file from delta table

# %%
location='/mnt/reqd'
def createDataFile(query,fname):
    df=spark.sql(query)
    loc=f"{location}/{fname}"
    df.write.format('json').mode('overwrite').option("header", "true").save(loc)

filename='policy1.json'
createDataFile("select * from policy where name in ('hrithik','rajiv')",filename)

# %%
# %fs
ls /mnt/reqd
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/mnt/reqd/policy1.json/</td><td>policy1.json/</td><td>0</td><td>0</td></tr></tbody></table></div>

# %%
display(spark.read.json("dbfs:/mnt/reqd/policy1.json"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>amount</th><th>created</th><th>name</th><th>policy</th></tr></thead><tbody><tr><td>13442.0</td><td>1999-03-15</td><td>hrithik</td><td>p0001</td></tr><tr><td>222.32</td><td>1991-03-15</td><td>rajiv</td><td>p0004</td></tr></tbody></table></div>

# %% [markdown]
# ### Read JSON files

# %%
from pyspark.sql.types import StructType, StructField, StringType, IntegerType
loc='/mnt/reqd'
dbfslanding='/mnt/dbfslandingzone'
schema = StructType([ 
    StructField("policy",StringType(),False), 
    StructField("name",StringType(),False), 
    StructField("created",StringType(),False), 
    StructField("amount", StringType(), False)
  ])

raw_df = spark.readStream.format('cloudFiles') \
.schema(schema) \
.option('cloudFiles.format','json') \
.option("header",True) \
.option('cloudFiles.schemaEvolutionMode','none') \
.option('cloudFiles.schemaLocation','/mnt/reqd/chk') \
.load(loc) #raw is the name of the source directory. Ensure to change it to the name of the container you have created as the source in the storage account

from pyspark.sql.functions import input_file_name, current_timestamp

transformed_df = (raw_df.select(
    "*",
    input_file_name().alias("source_file"),
    current_timestamp().alias("processing_time")
    )
                 )

# %%
transformed_df.writeStream \
    .trigger(availableNow=True) \
    .option("checkpointLocation", '/mnt/reqd/chk') \
    .option("path",dbfslanding) \
    .start()
# Out:
# Out[319]: <pyspark.sql.streaming.query.StreamingQuery at 0x7f8fca849df0>

# %%
spark.read.option("format","delta") \
.load(dbfslanding) \
.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>policy</th><th>name</th><th>created</th><th>amount</th><th>source_file</th><th>processing_time</th></tr></thead><tbody><tr><td>p0001</td><td>hrithik</td><td>1999-03-15</td><td>13442.0</td><td>/mnt/reqd/policy1.json/part-00000-tid-2056987125725837894-f6d84d2a-d0d6-46f1-9c9e-19fa435d1128-26511-1-c000.json</td><td>2023-04-21T13:22:38.516+0000</td></tr><tr><td>p0004</td><td>rajiv</td><td>1991-03-15</td><td>222.32</td><td>/mnt/reqd/policy1.json/part-00001-tid-2056987125725837894-f6d84d2a-d0d6-46f1-9c9e-19fa435d1128-26512-1-c000.json</td><td>2023-04-21T13:22:38.516+0000</td></tr></tbody></table></div>

# %% [markdown]
# ### Land new file

# %%
createDataFile("select * from policy where name='ram'",'policy2.json')

# %%
# %fs
ls /mnt/reqd
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/mnt/reqd/chk/</td><td>chk/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/mnt/reqd/policy1.json/</td><td>policy1.json/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/mnt/reqd/policy2.json/</td><td>policy2.json/</td><td>0</td><td>0</td></tr></tbody></table></div>

# %%
olddf = DeltaTable.forPath(spark, dbfslanding)

display(olddf.toDF())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>policy</th><th>name</th><th>created</th><th>amount</th><th>source_file</th><th>processing_time</th></tr></thead><tbody><tr><td>p0001</td><td>hrithik</td><td>1999-03-15</td><td>13442.0</td><td>/mnt/reqd/policy1.json/part-00000-tid-2056987125725837894-f6d84d2a-d0d6-46f1-9c9e-19fa435d1128-26511-1-c000.json</td><td>2023-04-21T13:22:38.516+0000</td></tr><tr><td>p0004</td><td>rajiv</td><td>1991-03-15</td><td>222.32</td><td>/mnt/reqd/policy1.json/part-00001-tid-2056987125725837894-f6d84d2a-d0d6-46f1-9c9e-19fa435d1128-26512-1-c000.json</td><td>2023-04-21T13:22:38.516+0000</td></tr></tbody></table></div>

# %% [markdown]
# ### Upsert

# %%
from delta.tables import *
olddf= DeltaTable.forPath(spark, dbfslanding)

def updateDeltaTable(batchDF, batchID):
    olddf.alias('t') \
    .merge(batchDF.alias('s'),'t.policy=s.policy') \
    .whenMatchedUpdateAll() \
    .whenNotMatchedInsertAll() \
    .execute()
    
    


transformed_df.writeStream \
    .foreachBatch(updateDeltaTable) \
    .outputMode('append') \
    .trigger(availableNow=True) \
    .option("checkpointLocation", '/mnt/reqd/chk') \
    .option("path",dbfslanding) \
    .start()
# Out:
# Out[324]: <pyspark.sql.streaming.query.StreamingQuery at 0x7f8fca5bdca0>

# %%
spark.read.option("format","delta") \
.load(dbfslanding) \
.dropna() \
.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>policy</th><th>name</th><th>created</th><th>amount</th><th>source_file</th><th>processing_time</th></tr></thead><tbody><tr><td>p0004</td><td>rajiv</td><td>1991-03-15</td><td>222.32</td><td>/mnt/reqd/policy1.json/part-00001-tid-2056987125725837894-f6d84d2a-d0d6-46f1-9c9e-19fa435d1128-26512-1-c000.json</td><td>2023-04-21T13:22:38.516+0000</td></tr><tr><td>p0001</td><td>ram</td><td>1908-03-15</td><td>232.0</td><td>/mnt/reqd/policy2.json/part-00000-tid-3734145666152764326-cc9c207e-4f4a-43a8-98c7-20bac493e6f7-26536-1-c000.json</td><td>2023-04-21T13:23:41.728+0000</td></tr></tbody></table></div>

# %% [markdown]
# ### Conclusion
# * Upsert seems to have worked row with policy number p0001 has changed from hritihik to ram
